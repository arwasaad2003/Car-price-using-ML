# %%
import pandas as pd
import numpy as np

import seaborn as sns
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data.csv')
len(df)
# Out:
# 11914

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)     335.00
# 1  BMW    1 Series  2011  premium unleaded (required)     300.00
# 2  BMW    1 Series  2011  premium unleaded (required)     300.00
# 3  BMW    1 Series  2011  premium unleaded (required)     230.00
# 4  BMW    1 Series  2011  premium unleaded (required)     230.00
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0              6.00            MANUAL  rear wheel drive             2.00
# 1              6.00            MANUAL  rear wheel drive             2.00
# 2              6.00            MANUAL  rear wheel drive             2.00
# 3              6.00            MANUAL  rear wheel drive             2.00
# 4              6.00            MANUAL  rear wheel drive             2.00
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

string_columns = list(df.dtypes[df.dtypes == 'object'].index)

for col in string_columns:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)     335.00
# 1  bmw    1_series  2011  premium_unleaded_(required)     300.00
# 2  bmw    1_series  2011  premium_unleaded_(required)     300.00
# 3  bmw    1_series  2011  premium_unleaded_(required)     230.00
# 4  bmw    1_series  2011  premium_unleaded_(required)     230.00
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0              6.00            manual  rear_wheel_drive             2.00
# 1              6.00            manual  rear_wheel_drive             2.00
# 2              6.00            manual  rear_wheel_drive             2.00
# 3              6.00            manual  rear_wheel_drive             2.00
# 4              6.00            manual  rear_wheel_drive             2.00
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %%
len(df.columns)
# Out:
# 16

# %%
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               11914 non-null  object
#  1   model              11914 non-null  object
#  2   year               11914 non-null  int64
#  3   engine_fuel_type   11911 non-null  object
#  4   engine_hp          11845 non-null  float64
#  5   engine_cylinders   11884 non-null  float64
#  6   transmission_type  11914 non-null  object
#  7   driven_wheels      11914 non-null  object
#  8   number_of_doors    11908 non-null  float64
#  9   market_category    8172 non-null   object
#  10  vehicle_size       11914 non-null  object
#  11  vehicle_style      11914 non-null  object
#  12  highway_mpg        11914 non-null  int64
#  13  city_mpg           11914 non-null  int64
#  14  popularity         11914 non-null  int64
#  15  msrp               11914 non-null  int64
# ...

# %%
for col in df.columns:
    print( col,':', df[col].nunique() )
    print(df[col].value_counts().nlargest(5))
    print('\n' + '*' * 20 + '\n')
# Out:
# make : 48
# chevrolet     1123
# ford           881
# volkswagen     809
# toyota         746
# dodge          626
# Name: make, dtype: int64
#
# ********************
#
# model : 914
# silverado_1500        156
# tundra                140
# f-150                 126
# sierra_1500            90
# beetle_convertible     89
# Name: model, dtype: int64
#
# ********************
#
# year : 28
# 2015    2170
# 2016    2157
# 2017    1668
# 2014     589
# 2012     387
# Name: year, dtype: int64
#
# ********************
#
# engine_fuel_type : 10
# regular_unleaded                  7172
# premium_unleaded_(required)       2009
# premium_unleaded_(recommended)    1523
# flex-fuel_(unleaded/e85)           899
# diesel                             154
# Name: engine_fuel_type, dtype: int64
#
# ********************
#
# engine_hp : 356
# 200.00    456
# 170.00    351
# 210.00    320
# 240.00    268
# 285.00    246
# Name: engine_hp, dtype: int64
#
# ********************
#
# engine_cylinders : 9
# ...

# %% [markdown]
# # Some Cleaning

# %%
df.columns = df.columns.str.lower().str.replace(' ', '_')

string_columns = list(df.dtypes[df.dtypes == 'object'].index)
print(string_columns)
for col in string_columns:
    df[col] = df[col].str.lower().str.replace(' ', '_')
# Out:
# ['make', 'model', 'engine_fuel_type', 'transmission_type', 'driven_wheels', 'market_category', 'vehicle_size', 'vehicle_style']

# %%
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 16

# %%
df.rename(columns = {'msrp': 'price'}, inplace = True)

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)     335.00
# 1  bmw    1_series  2011  premium_unleaded_(required)     300.00
# 2  bmw    1_series  2011  premium_unleaded_(required)     300.00
# 3  bmw    1_series  2011  premium_unleaded_(required)     230.00
# 4  bmw    1_series  2011  premium_unleaded_(required)     230.00
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0              6.00            manual  rear_wheel_drive             2.00
# 1              6.00            manual  rear_wheel_drive             2.00
# 2              6.00            manual  rear_wheel_drive             2.00
# 3              6.00            manual  rear_wheel_drive             2.00
# 4              6.00            manual  rear_wheel_drive             2.00
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %% [markdown]
# # Exploratory Data Analysis

# %%
pd.options.display.float_format='{:,.2f}'.format
df.describe()
# Out:
#            year  engine_hp  engine_cylinders  number_of_doors  highway_mpg  \
# count 11,914.00  11,845.00         11,884.00        11,908.00    11,914.00
# mean   2,010.38     249.39              5.63             3.44        26.64
# std        7.58     109.19              1.78             0.88         8.86
# min    1,990.00      55.00              0.00             2.00        12.00
# 25%    2,007.00     170.00              4.00             2.00        22.00
# 50%    2,015.00     227.00              6.00             4.00        26.00
# 75%    2,016.00     300.00              6.00             4.00        30.00
# max    2,017.00   1,001.00             16.00             4.00       354.00
#
#        city_mpg  popularity        price
# count 11,914.00   11,914.00    11,914.00
# mean      19.73    1,554.91    40,594.74
# std        8.99    1,441.86    60,109.10
# min        7.00        2.00     2,000.00
# 25%       16.00      549.00    21,000.00
# 50%       18.00    1,385.00    29,995.00
# ...

# %%
df.describe(include=['O'])
# Out:
#              make           model  engine_fuel_type transmission_type  \
# count       11914           11914             11911             11914
# unique         48             914                10                 5
# top     chevrolet  silverado_1500  regular_unleaded         automatic
# freq         1123             156              7172              8266
#
#             driven_wheels market_category vehicle_size vehicle_style
# count               11914            8172        11914         11914
# unique                  4              71            3            16
# top     front_wheel_drive       crossover      compact         sedan
# freq                 4787            1110         4764          3048

# %% [markdown]
# #  Target variable analysis (price)

# %%
plt.figure(figsize=(6, 4))

sns.histplot(df.price, bins=40)
plt.ylabel('Frequency')
plt.xlabel('Price')
plt.title('Distribution of prices')

plt.show()

# %%
plt.figure(figsize=(6, 4))

sns.histplot(df.price[df.price < 100000], bins=40, alpha=1)
plt.ylabel('Frequency')
plt.xlabel('Price')
plt.title('Distribution of prices')

plt.show()

# %% [markdown]
# # Log Transformation

# %%
df['log_price'] = np.log1p(df.price)

plt.figure(figsize=(6, 4))

sns.histplot(df.log_price, bins=40)
plt.ylabel('Frequency')
plt.xlabel('Log(Price + 1)')
plt.title('Distribution of prices after log tranformation')

plt.show()

# %%
df.price.skew()
# Out:
# 11.771987129334972

# %%
df.log_price.skew()
# Out:
# -0.9178678067039072

# %% [markdown]
# # Check missing values

# %%
df.isnull().sum()
# Out:
# make                    0
# model                   0
# year                    0
# engine_fuel_type        3
# engine_hp              69
# engine_cylinders       30
# transmission_type       0
# driven_wheels           0
# number_of_doors         6
# market_category      3742
# vehicle_size            0
# vehicle_style           0
# highway_mpg             0
# city_mpg                0
# popularity              0
# price                   0
# log_price               0
# dtype: int64

# %% [markdown]
# # Check categorical columns

# %%
string_columns
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
df.make.value_counts()
# Out:
# chevrolet        1123
# ford              881
# volkswagen        809
# toyota            746
# dodge             626
# nissan            558
# gmc               515
# honda             449
# mazda             423
# cadillac          397
# mercedes-benz     353
# suzuki            351
# bmw               334
# infiniti          330
# audi              328
# hyundai           303
# volvo             281
# subaru            256
# acura             252
# kia               231
# mitsubishi        213
# lexus             202
# buick             196
# chrysler          187
# pontiac           186
# lincoln           164
# oldsmobile        150
# land_rover        143
# porsche           136
# saab              111
# aston_martin       93
# plymouth           82
# bentley            74
# ferrari            69
# fiat               62
# scion              60
# maserati           58
# lamborghini        52
# rolls-royce        31
# lotus              29
# tesla              18
# ...

# %%
df.groupby('make').mean()
# Out:
# C:\Users\Elasad\AppData\Local\Temp\ipykernel_11532\3049139737.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('make').mean()
#                   year  engine_hp  engine_cylinders  number_of_doors  \
# make
# acura         2,010.06     244.80              5.33             3.62
# alfa_romeo    2,015.40     237.00              4.00             2.00
# aston_martin  2,013.02     484.32             10.62             2.15
# audi          2,012.23     277.70              5.56             3.47
# bentley       2,011.70     533.85              9.73             2.68
# bmw           2,014.35     326.91              5.96             3.16
# bugatti       2,008.33   1,001.00             16.00             2.00
# buick         2,010.01     219.24              5.32             3.84
# ...

# %%
df.groupby('make').mean()['price']['bmw']
# Out:
# C:\Users\Elasad\AppData\Local\Temp\ipykernel_11532\436252036.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('make').mean()['price']['bmw']
# 61546.76347305389

# %%
df[df['year'] >= 2015]
# Out:
#        make       model  year                engine_fuel_type  engine_hp  \
# 32     fiat  124_spider  2017  premium_unleaded_(recommended)     160.00
# 33     fiat  124_spider  2017  premium_unleaded_(recommended)     160.00
# 34     fiat  124_spider  2017  premium_unleaded_(recommended)     160.00
# 41      bmw    2_series  2016     premium_unleaded_(required)     240.00
# 42      bmw    2_series  2016     premium_unleaded_(required)     240.00
# ...     ...         ...   ...                             ...        ...
# 11898   bmw          z4  2015     premium_unleaded_(required)     300.00
# 11899   bmw          z4  2015     premium_unleaded_(required)     335.00
# 11900   bmw          z4  2016     premium_unleaded_(required)     300.00
# 11901   bmw          z4  2016     premium_unleaded_(required)     240.00
# 11902   bmw          z4  2016     premium_unleaded_(required)     335.00
#
#        engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# ...

# %% [markdown]
# # Validation framework

# %% [markdown]
# ![68747470733a2f2f766974616c666c75782e636f6d2f77702d636f6e74656e742f75706c6f6164732f323032302f31322f486f6c642d6f75742d6d6574686f642d666f722d6d6f64656c2d73656c656374696f6e2e706e67.png](attachment:68747470733a2f2f766974616c666c75782e636f6d2f77702d636f6e74656e742f75706c6f6164732f323032302f31322f486f6c642d6f75742d6d6574686f642d666f722d6d6f64656c2d73656c656374696f6e2e706e67.png)

# %%
np.random.seed(2)     # Fixes the random seed to make sure that the results are reproducible

n = len(df) 

n_val = int(0.2 * n)
n_test = int(0.2 * n)
n_train = n - (n_val + n_test)

print('No. of rows for training : ', n_train)
print('No. of rows for validation : ', n_val)
print('No. of rows for testing : ', n_test)
# Out:
# No. of rows for training :  7150
# No. of rows for validation :  2382
# No. of rows for testing :  2382

# %%
idx = np.arange(n)
print(idx)
print('-------------------------------------------------------')
np.random.shuffle(idx)
print(idx)
print('-------------------------------------------------------')
df_shuffled = df.iloc[idx]
print(df.index)
print('-------------------------------------------------------')

print(df_shuffled.index)
df_shuffled
# Out:
# [    0     1     2 ... 11911 11912 11913]
# -------------------------------------------------------
# [2735 6720 5878 ... 6637 2575 7336]
# -------------------------------------------------------
# RangeIndex(start=0, stop=11914, step=1)
# -------------------------------------------------------
# Int64Index([ 2735,  6720,  5878, 11190,  4554,  8001,  2882,   649,   616,
#              4459,
#             ...
#              6751,   433,  4770, 11527,  1099,  2514, 11798,  6637,  2575,
#              7336],
#            dtype='int64', length=11914)
#              make         model  year          engine_fuel_type  engine_hp  \
# 2735    chevrolet        cobalt  2008          regular_unleaded     148.00
# 6720       toyota        matrix  2012          regular_unleaded     132.00
# 5878       subaru       impreza  2016          regular_unleaded     148.00
# 11190  volkswagen       vanagon  1991          regular_unleaded      90.00
# ...

# %%
df
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          bmw  1_series_m  2011     premium_unleaded_(required)     335.00
# 1          bmw    1_series  2011     premium_unleaded_(required)     300.00
# 2          bmw    1_series  2011     premium_unleaded_(required)     300.00
# 3          bmw    1_series  2011     premium_unleaded_(required)     230.00
# 4          bmw    1_series  2011     premium_unleaded_(required)     230.00
# ...        ...         ...   ...                             ...        ...
# 11909    acura         zdx  2012     premium_unleaded_(required)     300.00
# 11910    acura         zdx  2012     premium_unleaded_(required)     300.00
# 11911    acura         zdx  2012     premium_unleaded_(required)     300.00
# 11912    acura         zdx  2013  premium_unleaded_(recommended)     300.00
# 11913  lincoln      zephyr  2006                regular_unleaded     221.00
#
# ...

# %%
df_train=df_shuffled.iloc[:n_train].copy()
df_val=df_shuffled.iloc[n_train:n_train+n_val].copy()
df_test=df_shuffled.iloc[n_train+n_val].copy()

# %%
df_train
# Out:
#               make        model  year                engine_fuel_type  \
# 2735     chevrolet       cobalt  2008                regular_unleaded
# 6720        toyota       matrix  2012                regular_unleaded
# 5878        subaru      impreza  2016                regular_unleaded
# 11190   volkswagen      vanagon  1991                regular_unleaded
# 4554          ford        f-150  2017        flex-fuel_(unleaded/e85)
# ...            ...          ...   ...                             ...
# 434            bmw     4_series  2015     premium_unleaded_(required)
# 1902    volkswagen       beetle  2015  premium_unleaded_(recommended)
# 9334           gmc  sierra_1500  2015        flex-fuel_(unleaded/e85)
# 5284   rolls-royce        ghost  2014     premium_unleaded_(required)
# 2420    volkswagen           cc  2017  premium_unleaded_(recommended)
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df_val
# Out:
#                 make                    model  year  \
# 2779       chevrolet                 colorado  2015
# 3708   mercedes-benz                  e-class  2017
# 4794            ford                    focus  2017
# 10498          acura                      tlx  2016
# 1880      volkswagen       beetle_convertible  2016
# ...              ...                      ...   ...
# 11123          volvo                      v60  2015
# 5549        maserati  granturismo_convertible  2015
# 4146        cadillac          escalade_hybrid  2013
# 6337      mitsubishi                   lancer  2016
# 9814             kia                  sorento  2015
#
#                      engine_fuel_type  engine_hp  engine_cylinders  \
# 2779                 regular_unleaded     200.00              4.00
# 3708      premium_unleaded_(required)     241.00              4.00
# 4794         flex-fuel_(unleaded/e85)     160.00              4.00
# ...

# %%
df_test
# Out:
# make                              gmc
# model                         vandura
# year                             1994
# engine_fuel_type     regular_unleaded
# engine_hp                      165.00
# engine_cylinders                 6.00
# transmission_type           automatic
# driven_wheels        rear_wheel_drive
# number_of_doors                  3.00
# market_category                   NaN
# vehicle_size                  compact
# vehicle_style               cargo_van
# highway_mpg                        20
# city_mpg                           15
# popularity                        549
# price                            2000
# log_price                        7.60
# Name: 11195, dtype: object

# %%
df_test.shape
# Out:
# (17,)

# %%
y_train = df_train.log_price.values
y_val = df_val.log_price.values
#y_test = df_test.log_price.values

# %%
y_test = np.array([df_test.log_price]).reshape(-1, 1)

# %%
base = ['engine_hp', 'engine_cylinders', 'highway_mpg', 'city_mpg', 'popularity']   # Think about Numerical only

# %%
df[base]
# Out:
#        engine_hp  engine_cylinders  highway_mpg  city_mpg  popularity
# 0         335.00              6.00           26        19        3916
# 1         300.00              6.00           28        19        3916
# 2         300.00              6.00           28        20        3916
# 3         230.00              6.00           28        18        3916
# 4         230.00              6.00           28        18        3916
# ...          ...               ...          ...       ...         ...
# 11909     300.00              6.00           23        16         204
# 11910     300.00              6.00           23        16         204
# 11911     300.00              6.00           23        16         204
# 11912     300.00              6.00           23        16         204
# 11913     221.00              6.00           26        17          61
#
# [11914 rows x 5 columns]

# %%
df[base].isnull().sum()
# Out:
# engine_hp           69
# engine_cylinders    30
# highway_mpg          0
# city_mpg             0
# popularity           0
# dtype: int64

# %% [markdown]
# #  Handling Missing Values

# %%
def prepare_X(df):
    df_num=df[base]
    df_num=df-num.fillan()

# %% [markdown]
# #  Linear Regression

# %% [markdown]
# ![68747470733a2f2f6d69726f2e6d656469756d2e636f6d2f6d61782f313430302f312a475341634e3947377374554a5162754f6875304845672e706e67.png](attachment:68747470733a2f2f6d69726f2e6d656469756d2e636f6d2f6d61782f313430302f312a475341634e3947377374554a5162754f6875304845672e706e67.png)

# %%
df_train.corr()
# Out:
# C:\Users\Elasad\AppData\Local\Temp\ipykernel_11532\299540020.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df_train.corr()
#                   year  engine_hp  engine_cylinders  number_of_doors  \
# year              1.00       0.36             -0.04             0.26
# engine_hp         0.36       1.00              0.78            -0.10
# engine_cylinders -0.04       0.78              1.00            -0.14
# number_of_doors   0.26      -0.10             -0.14             1.00
# highway_mpg       0.25      -0.39             -0.60             0.11
# city_mpg          0.20      -0.44             -0.60             0.12
# popularity        0.08       0.04              0.04            -0.05
# price             0.22       0.65              0.51            -0.12
# ...

# %%
plt.figure(figsize=(15,8))
_=sns.heatmap(df_train.corr(),annot=True)
# Out:
# C:\Users\Elasad\AppData\Local\Temp\ipykernel_11532\3604172490.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   _=sns.heatmap(df_train.corr(),annot=True)

# %%
def linear_regression(xi):
    n =len(xi)                # Number of features used
    
    pred = w0                 # Initial / Base prediction
    
    for j in range(n):
        pred += w[j]*xi[j]     # Formula = w0 +sigma[0:n-1]{w[j]*xi[j]}
    
    return pred

# %%
def train_linear_regression(X, y):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    XTX = X.T.dot(X)
    XTX_inv = np.linalg.inv(XTX)
    w = XTX_inv.dot(X.T).dot(y)
    
    return w[0], w[1:]

# %%
def prepare_X(df):
    df_num = df[base]  # Assuming 'base' is a list of columns you want to select
    df_num = df_num.fillna(0)  # Replace missing values with 0 (or another value/method as needed)
    return df_num

# %%
X_train = prepare_X(df_train)
w_0, w = train_linear_regression(X_train, y_train)
y_pred = w_0 + X_train.dot(w)

# %%
sns.histplot(y_train, label='target')
sns.histplot(y_pred, label='prediction', color='red')

plt.legend()

plt.ylabel('Frequency')
plt.xlabel('Log(Price + 1)')
plt.title('Predictions vs actual distribution')

plt.show()

# %% [markdown]
# # Model Evaluation

# %%
def rmse(y,y_pred):
    error=y_pred -y
    mse=(error**2).mean()
    return np.sqrt(mse)

# %%
rmse(y_train, y_pred)
# Out:
# 0.7554192603920132

# %%
X_val = prepare_X(df_val)
y_pred = w_0 + X_val.dot(w)

# %%
rmse(y_val, y_pred)
# Out:
# 0.7616530991301601

# %% [markdown]
# # Simple Feature Engineering

# %%
sorted(df.year.unique())
# Out:
# [1990,
#  1991,
#  1992,
#  1993,
#  1994,
#  1995,
#  1996,
#  1997,
#  1998,
#  1999,
#  2000,
#  2001,
#  2002,
#  2003,
#  2004,
#  2005,
#  2006,
#  2007,
#  2008,
#  2009,
#  2010,
#  2011,
#  2012,
#  2013,
#  2014,
#  2015,
#  2016,
#  2017]

# %%
def prepare_X(df):
    df = df.copy()
    features = base.copy()

    df['age'] = 2017 - df.year    # Because the dataset was created in 2017 (which we can verify by checking df_train.year.max())
    features.append('age')
    
    df_num = df[features]
    df_num = df_num.fillna(df_num.mean())
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w_0, w = train_linear_regression(X_train, y_train)
y_pred = w_0 + X_train.dot(w)
print('Train RMSE: ', rmse(y_train, y_pred))

X_val = prepare_X(df_val)
y_pred = w_0 + X_val.dot(w)
print('Validation RMSE: ', rmse(y_val, y_pred))
# Out:
# Train RMSE:  0.5117454503079417
# Validation RMSE:  0.5070033906013027

# %%
plt.figure(figsize=(6, 4))


sns.histplot(y_val, label='target', color='blue', alpha=0.9, bins=40)
sns.histplot(y_pred, label='prediction', color='green', alpha=0.8, bins=40)

plt.legend()

plt.ylabel('Frequency')
plt.xlabel('Log(Price + 1)')
plt.title('Predictions vs actual distribution')

plt.show()

# %% [raw]
# 1-Reading Data
# 2-Some Cleaning
# 3-Exploratory Data Analysis
# 4-Target variable analysis (price)
# 5-Log Transformation
# 6-Check missing values
# 7-Validation framework
# 8-Baseline solution
# 9-Handling Missing Values
# 10-Linear Regression
# 11-Model Evaluation
# 12-Simple Feature Engineering

# %% [markdown]
# هذا من فضل ربي الحمد لله
